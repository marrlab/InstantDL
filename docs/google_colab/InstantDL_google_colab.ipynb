# %% [markdown]
# **InstantDL with GoogleColab.**
#
# Firstly mount a GPU: Edit-> Notebook settings-> Select GPU as Hardware accelerator
#
# You have to upload your data to your GoogleDrive and then mount the GoogleDrive in GoogleColab with (it will ask you to enter your google-password or to verify your Google account):

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# *Make* the path to your data directory visible to GoogleColab

# %%
import os
os.chdir('/content/drive/My Drive/')
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %% [markdown]
# Install InstantDL with pip install and adapt tensorflow and keras version

# %%
# !pip install instantdl
# !pip install tensorflow==1.15.2
# !pip install tensorflow-gpu==1.15.2
# !pip install keras==2.2.4
# Out:
# ...
#      |████████████████████████████████| 112kB 25.7MB/s
# ...
#      |████████████████████████████████| 3.8MB 40.7MB/s
# ...
# ERROR: tensorflow 2.4.1 has requirement tensorboard~=2.4, but you'll have tensorboard 1.15.0 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
# ...
#      |████████████████████████████████| 110.5MB 59kB/s
# ...
#      |████████████████████████████████| 51kB 8.9MB/s
# ...
#      |████████████████████████████████| 512kB 47.6MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=833056b6d8fe79ec44015bd172cbf04ee75c1e6d29fdf8d2acae1ac6996cd8bd
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
# ...

# %% [markdown]
# Import the deep learning pipeline from InstantDL

# %%
from instantdl import GetPipeLine
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/instantdl/segmentation/SemanticSegmentation.py:13: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/instantdl/segmentation/SemanticSegmentation.py:13: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/instantdl/segmentation/SemanticSegmentation.py:14: The name tf.random.set_random_seed is deprecated. Please use tf.compat.v1.random.set_random_seed instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/instantdl/segmentation/SemanticSegmentation.py:14: The name tf.random.set_random_seed is deprecated. Please use tf.compat.v1.random.set_random_seed instead.

# %% [markdown]
# Please specify the configs and run InstantDL with the cell below

# %%
configs = { "use_algorithm" : "InstanceSegmentation",
           "path" : "/content/drive/MyDrive/image_computing_course/Instantdl_segmentation",
           "pretrained_weights" : "/content/drive/MyDrive/image_computing_course/Instantdl_segmentation/Nuclei_in_divergent_image_Instance_Segmentation_weights.h5", 
            "batchsize" : 1, 
            "iterations_over_dataset" : 0, 
            "data_gen_args" : False, 
            "loss_function" : "mse", 
            "calculate_uncertainty" : False,
            "evaluation" : False}

P = GetPipeLine(configs=configs)
P.run()
# Out:
# INFO:root:
# Configurations:
# INFO:root:BACKBONE                       resnet50
# INFO:root:BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# INFO:root:BATCH_SIZE                     1
# INFO:root:BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# INFO:root:COMPUTE_BACKBONE_SHAPE         None
# INFO:root:DETECTION_MAX_INSTANCES        400
# INFO:root:DETECTION_MIN_CONFIDENCE       0.85
# INFO:root:DETECTION_NMS_THRESHOLD        0.3
# INFO:root:FPN_CLASSIF_FC_LAYERS_SIZE     1024
# INFO:root:GPU_COUNT                      1
# INFO:root:GRADIENT_CLIP_NORM             5.0
# INFO:root:IMAGES_PER_GPU                 1
# INFO:root:IMAGE_CHANNEL_COUNT            3
# INFO:root:IMAGE_MAX_DIM                  512
# INFO:root:IMAGE_META_SIZE                14
# INFO:root:IMAGE_MIN_DIM                  256
# INFO:root:IMAGE_MIN_SCALE                0
# INFO:root:IMAGE_RESIZE_MODE              crop
# INFO:root:IMAGE_SHAPE                    [256 256   3]
# ...

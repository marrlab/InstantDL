# %% [markdown]
# **InstantDL with GoogleColab.**
#
# Firstly mount a GPU: Edit-> Notebook settings-> Select GPU as Hardware accelerator
#
# You have to upload your data to your GoogleDrive and then mount the GoogleDrive in GoogleColab with (it will ask you to enter your google-password):

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# *Make* the path to your data directory visible to GoogleColab

# %%
import os
os.chdir("""/content/drive/My Drive/InstantDL/""")

# %% [markdown]
# Import the path to InstantDL

# %%
import sys
sys.path.append('/content/drive/My Drive/InstantDL/')

# %% [markdown]
# Import the deep learning pipeline from InstantDL

# %%
from instantdl import GetPipeLine
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Execute the pipeline with the desired settings, which should be added below in the same order as in the confing.json file. By executing the next line InstantDL will run.

# %%
P = GetPipeLine('Regression','/content/drive/My Drive/InstantDL/docs/examples/data/Regression',None,1,2,{'save_augmented_images': False, 'resample_images': False,'std_normalization': False},'binary_crossentropy',1,None,True,True)
P.run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-587378346a53> in <module>()
#       1 P = GetPipeLine('Regression','/content/drive/My Drive/InstantDL/docs/examples/data/Regression',None,1,2,{'save_augmented_images': False, 'resample_images': False,'std_normalization': False},'binary_crossentropy',1,None,True,True)
# ----> 2 P.run()
#
# /content/drive/My Drive/InstantDL/instantdl/segmentation/Regression.py in run(self)
#     258
#     259     def run(self):
# --> 260         data_prepration_results = self.data_prepration()
#     261
#     262         Training_Input_shape = data_prepration_results[0]
#
# /content/drive/My Drive/InstantDL/instantdl/segmentation/Regression.py in data_prepration(self)
#      43         '''
#      44         if self.image_size == None:
# ---> 45             Training_Input_shape, num_channels, Input_image_shape = get_input_image_sizes(self.path, self.use_algorithm)
#      46         else:
#      47             Training_Input_shape = self.image_size
#
# /content/drive/My Drive/InstantDL/instantdl/data_generator/data_generator.py in get_input_image_sizes(path, use_algorithm)
#     408     '''
#     409     data_path = path + '/train'
# --> 410     img_file = os.listdir(data_path + "/image/")[0]
#     411     Input_image_shape = np.array(np.shape(np.array(import_image(data_path + "/image/" + img_file))))
#     412     logging.info("Input shape Input_image_shape %s" % Input_image_shape)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/InstantDL/docs/examples/data/Regression/train/image/'

# %% [markdown]
# The config parameters to choose from are, with examples filled in:
#
#
# {
# 	"use_algorithm": "SemanticSegmentation",
# 	"path": "/Users/dominik.waibel/Desktop/InstantDL/docs/examples/dsb/",
# 	"pretrained_weights_path": "/Users/dominik.waibel/Desktop/InstantDL/docs/examples/dsb/pretrained_weights_combined_data_mse.hdf5",
# 	"batchsize": 1,
# 	"iterations_over_dataset": 0,
# 	"data_gen_args": {
# 			"save_augmented_images": false,
# 		            "resample_images": false,
# 		            "std_normalization": false,
# 		            "feature_scaling": false,
# 		            "horizontal_flip": false,
# 		            "vertical_flip": true,
# 		            "poission_noise": false,
# 		            "rotation_range": false,
# 		            "zoom_range": false,
# 		            "contrast_range": false,
# 		            "brightness_range": false,
# 		            "gamma_shift": false,
# 		            "threshold_background_image": false,
# 		            "threshold_background_groundtruth": false,
# 		            "binarize_mask": false
# 	},
# 	"loss_function": "mse",
# 	"num_classes": 1,
# 	"image_size": null,
# 	"calculate_uncertainty": true,
# 	"evaluation": true
# }
